# %% [markdown]
# **STEP #1: IMPORTING DATA**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from prophet import Prophet
import random

# %%
chicago_df_1 = pd.read_csv('Chicago_Crimes_2005_to_2007.csv', on_bad_lines = 'skip')
chicago_df_2 = pd.read_csv('Chicago_Crimes_2008_to_2011.csv', on_bad_lines = 'skip')
chicago_df_3 = pd.read_csv('Chicago_Crimes_2012_to_2017.csv', on_bad_lines = 'skip')

# %%
chicago_df = pd.concat([chicago_df_1, chicago_df_2, chicago_df_3], ignore_index=False, axis=0)

# %%
chicago_df.shape
# Out:
# (6017767, 23)

# %% [markdown]
# **STEP #2: EXPLORING THE DATASET**

# %%
chicago_df.head(10)
# Out:
#    Unnamed: 0       ID Case Number                    Date  \
# 0           0  4673626    HM274058  04/02/2006 01:00:00 PM
# 1           1  4673627    HM202199  02/26/2006 01:40:48 PM
# 2           2  4673628    HM113861  01/08/2006 11:16:00 PM
# 3           4  4673629    HM274049  04/05/2006 06:45:00 PM
# 4           5  4673630    HM187120  02/17/2006 09:03:14 PM
# 5           6  4673631    HM263167  03/30/2006 10:30:00 PM
# 6           7  4673632    HM273234  04/05/2006 12:10:00 PM
# 7           8  4673633    HM275105  04/05/2006 03:00:00 PM
# 8           9  4673634    HM275063  04/05/2006 09:30:00 PM
# 9          10  4673635    HM268513  04/03/2006 03:00:00 AM
#
#                   Block  IUCR   Primary Type                   Description  \
# 0     055XX N MANGO AVE  2825  OTHER OFFENSE       HARASSMENT BY TELEPHONE
# 1    065XX S RHODES AVE  2017      NARCOTICS            MANU/DELIVER:CRACK
# 2       013XX E 69TH ST  051A        ASSAULT           AGGRAVATED: HANDGUN
# 3   061XX W NEWPORT AVE  0460        BATTERY                        SIMPLE
# 4       037XX W 60TH ST  1811      NARCOTICS  POSS: CANNABIS 30GMS OR LESS
# 5       014XX W 73RD PL  0560        ASSAULT                        SIMPLE
# 6   050XX N LARAMIE AVE  0460        BATTERY                        SIMPLE
# 7   067XX S ROCKWELL ST  0820          THEFT                $500 AND UNDER
# 8   019XX W CHICAGO AVE  0560        ASSAULT                        SIMPLE
# 9  063XX S EBERHART AVE  0486        BATTERY       DOMESTIC BATTERY SIMPLE
#
#              Location Description  Arrest  ...  Ward  Community Area  \
# 0                       RESIDENCE   False  ...  45.0            11.0
# 1                        SIDEWALK    True  ...  20.0            42.0
# 2                           OTHER   False  ...   5.0            69.0
# 3                       RESIDENCE   False  ...  38.0            17.0
# 4                           ALLEY    True  ...  13.0            65.0
# 5                       APARTMENT    True  ...  17.0            67.0
# 6        SCHOOL, PUBLIC, BUILDING    True  ...  45.0            11.0
# 7                          STREET   False  ...  15.0            66.0
# 8  PARKING LOT/GARAGE(NON.RESID.)   False  ...  32.0            24.0
# 9                        SIDEWALK   False  ...  20.0            42.0
#
#    FBI Code  X Coordinate  Y Coordinate  Year              Updated On  \
#
# ...                                             ...     ...       ...
# 2016-05-03 23:33:00                       APARTMENT    True      True
# 2016-05-03 23:30:00                       APARTMENT    True      True
# 2016-05-03 00:15:00                        SIDEWALK   False     False
# 2016-05-03 21:07:00                        SIDEWALK   False      True
# 2016-05-03 23:38:00  PARKING LOT/GARAGE(NON.RESID.)    True     False
#
# [6017767 rows x 8 columns]

# %%
chicago_df.resample('Y').size()
# Out:
# <ipython-input-46-45ca8699d18e>:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   chicago_df.resample('Y').size()
# Date
# 2005-12-31    455811
# 2006-12-31    794684
# 2007-12-31    621848
# 2008-12-31    852053
# 2009-12-31    783900
# 2010-12-31    700691
# 2011-12-31    352066
# 2012-12-31    335670
# 2013-12-31    306703
# 2014-12-31    274527
# 2015-12-31    262995
# 2016-12-31    265462
# 2017-12-31     11357
# Freq: YE-DEC, dtype: int64

# %%
plt.plot(chicago_df.resample('Y').size())
plt.title('Crimes Count Per Year')
plt.xlabel('Years')
plt.ylabel('Number of Crimes')
# Out:
# <ipython-input-47-7220f9566c33>:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   plt.plot(chicago_df.resample('Y').size())
# Text(0, 0.5, 'Number of Crimes')

# %%
chicago_df.resample('M').size()
# Out:
# <ipython-input-48-cd7733d5f406>:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   chicago_df.resample('M').size()
# Date
# 2005-01-31    33983
# 2005-02-28    32042
# 2005-03-31    36970
# 2005-04-30    38963
# 2005-05-31    40572
#               ...
# 2016-09-30    23235
# 2016-10-31    23314
# 2016-11-30    21140
# 2016-12-31    19580
# 2017-01-31    11357
# Freq: ME, Length: 145, dtype: int64

# %%
plt.plot(chicago_df.resample('M').size())
plt.title('Crimes Count Per Month')
plt.xlabel('Months')
plt.ylabel('Number of Crimes')
# Out:
# <ipython-input-49-5396ad7954a8>:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   plt.plot(chicago_df.resample('M').size())
# Text(0, 0.5, 'Number of Crimes')

# %%
chicago_df.resample('Q').size()
# Out:
# <ipython-input-50-f33e7738ba4b>:1: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   chicago_df.resample('Q').size()
# Date
# 2005-03-31    102995
# 2005-06-30    119769
# 2005-09-30    123550
# 2005-12-31    109497
# 2006-03-31    115389
# 2006-06-30    225489
# 2006-09-30    238423
# 2006-12-31    215383
# 2007-03-31    192791
# 2007-06-30    204361
# 2007-09-30    119086
# 2007-12-31    105610
# 2008-03-31    191523
# 2008-06-30    222331
# 2008-09-30    236695
# 2008-12-31    201504
# 2009-03-31    184055
# 2009-06-30    203916
# 2009-09-30    210446
# 2009-12-31    185483
# 2010-03-31    171848
# 2010-06-30    194453
# 2010-09-30    197116
# 2010-12-31    137274
# 2011-03-31     78167
# 2011-06-30     93064
# 2011-09-30     95835
# 2011-12-31     85000
# 2012-03-31     78574
# 2012-06-30     88283
# 2012-09-30     89685
# 2012-12-31     79128
# 2013-03-31     71651
# 2013-06-30     80776
# 2013-09-30     83510
# 2013-12-31     70766
# 2014-03-31     59964
# 2014-06-30     72991
# 2014-09-30     76090
# 2014-12-31     65482
# 2015-03-31     58503
# 2015-06-30     68239
# 2015-09-30     71782
# 2015-12-31     64471
# 2016-03-31     60843
# 2016-06-30     68085
# 2016-09-30     72500
# 2016-12-31     64034
# 2017-03-31     11357
# Freq: QE-DEC, dtype: int64

# %%
plt.plot(chicago_df.resample('Q').size())
plt.title('Crimes Count Per Quarter')
plt.xlabel('Quarters')
plt.ylabel('Number of Crimes')
# Out:
# <ipython-input-51-a4d0dc1d143e>:1: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   plt.plot(chicago_df.resample('Q').size())
# Text(0, 0.5, 'Number of Crimes')

# %% [markdown]
# **STEP #3: PREPARING THE DATA**

# %%
chicago_prophet = chicago_df.resample('M').size().reset_index()
# Out:
# <ipython-input-52-406ed1a9b398>:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   chicago_prophet = chicago_df.resample('M').size().reset_index()

# %%
chicago_prophet
# Out:
#           Date      0
# 0   2005-01-31  33983
# 1   2005-02-28  32042
# 2   2005-03-31  36970
# 3   2005-04-30  38963
# 4   2005-05-31  40572
# ..         ...    ...
# 140 2016-09-30  23235
# 141 2016-10-31  23314
# 142 2016-11-30  21140
# 143 2016-12-31  19580
# 144 2017-01-31  11357
#
# [145 rows x 2 columns]

# %%
chicago_prophet.columns = ['Date', 'Crime Count']
chicago_prophet
# Out:
#           Date  Crime Count
# 0   2005-01-31        33983
# 1   2005-02-28        32042
# 2   2005-03-31        36970
# 3   2005-04-30        38963
# 4   2005-05-31        40572
# ..         ...          ...
# 140 2016-09-30        23235
# 141 2016-10-31        23314
# 142 2016-11-30        21140
# 143 2016-12-31        19580
# 144 2017-01-31        11357
#
# [145 rows x 2 columns]

# %%
chicago_prophet_df = pd.DataFrame(chicago_prophet)
chicago_prophet_df
# Out:
#           Date  Crime Count
# 0   2005-01-31        33983
# 1   2005-02-28        32042
# 2   2005-03-31        36970
# 3   2005-04-30        38963
# 4   2005-05-31        40572
# ..         ...          ...
# 140 2016-09-30        23235
# 141 2016-10-31        23314
# 142 2016-11-30        21140
# 143 2016-12-31        19580
# 144 2017-01-31        11357
#
# [145 rows x 2 columns]

# %% [markdown]
# **STEP #4: MAKE PREDICTIONS**

# %%
chicago_prophet_df.columns
# Out:
# Index(['Date', 'Crime Count'], dtype='object')

# %%
chicago_prophet_df_final = chicago_prophet_df.rename(columns={'Date':'ds', 'Crime Count':'y'})

# %%
chicago_prophet_df_final
# Out:
#             ds      y
# 0   2005-01-31  33983
# 1   2005-02-28  32042
# 2   2005-03-31  36970
# 3   2005-04-30  38963
# 4   2005-05-31  40572
# ..         ...    ...
# 140 2016-09-30  23235
# 141 2016-10-31  23314
# 142 2016-11-30  21140
# 143 2016-12-31  19580
# 144 2017-01-31  11357
#
# [145 rows x 2 columns]

# %%
m = Prophet()
m.fit(chicago_prophet_df_final)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpppfcy4lh/aqnsex3s.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpppfcy4lh/3fau_3kz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8409', 'data', 'file=/tmp/tmpppfcy4lh/aqnsex3s.json', 'init=/tmp/tmpppfcy4lh/3fau_3kz.json', 'output', 'file=/tmp/tmpppfcy4lh/prophet_model96rz9vhf/prophet_model-20241226142250.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:22:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:22:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)

# %%
forecast
# Out:
#             ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0   2005-01-31  60454.750250  38596.934439  72178.433952  60454.750250
# 1   2005-02-28  60322.347154  35240.220139  67689.485479  60322.347154
# 2   2005-03-31  60175.758011  41848.176883  77000.798840  60175.758011
# 3   2005-04-30  60033.897551  44259.396978  78030.060666  60033.897551
# 4   2005-05-31  59887.308409  48372.861724  81427.884251  59887.308409
# ..         ...           ...           ...           ...           ...
# 505 2018-01-27  10103.681533 -11248.748848  22390.875605   9958.109008
# 506 2018-01-28  10090.614711 -11622.598042  20795.741180   9944.334070
# 507 2018-01-29  10077.547889  -9998.807650  21803.354611   9930.559133
# 508 2018-01-30  10064.481066 -10999.861524  21704.850152   9916.784195
# 509 2018-01-31  10051.414244 -12205.619543  22454.715824   9903.009257
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0    60454.750250    -4762.406203          -4762.406203          -4762.406203
# 1    60322.347154    -9500.516982          -9500.516982          -9500.516982
# 2    60175.758011    -1224.153855          -1224.153855          -1224.153855
# 3    60033.897551     1182.825528           1182.825528           1182.825528
# 4    59887.308409     5498.249807           5498.249807           5498.249807
# ..            ...             ...                   ...                   ...
# 505  10243.169480    -4977.961503          -4977.961503          -4977.961503
# 506  10230.937093    -4922.604205          -4922.604205          -4922.604205
# 507  10218.692897    -4867.918336          -4867.918336          -4867.918336
# 508  10206.448701    -4816.735671          -4816.735671          -4816.735671
# 509  10194.050849    -4772.144938          -4772.144938          -4772.144938
#
#           yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0   -4762.406203  -4762.406203  -4762.406203                   0.0
# 1   -9500.516982  -9500.516982  -9500.516982                   0.0
# 2   -1224.153855  -1224.153855  -1224.153855                   0.0
# 3    1182.825528   1182.825528   1182.825528                   0.0
# 4    5498.249807   5498.249807   5498.249807                   0.0
# ..           ...           ...           ...                   ...
# 505 -4977.961503  -4977.961503  -4977.961503                   0.0
# 506 -4922.604205  -4922.604205  -4922.604205                   0.0
# 507 -4867.918336  -4867.918336  -4867.918336                   0.0
# 508 -4816.735671  -4816.735671  -4816.735671                   0.0
# 509 -4772.144938  -4772.144938  -4772.144938                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                           0.0                         0.0  55692.344047
# 1                           0.0                         0.0  50821.830172
# 2                           0.0                         0.0  58951.604157
# 3                           0.0                         0.0  61216.723079
# 4                           0.0                         0.0  65385.558216
# ..                          ...                         ...           ...
# 505                         0.0                         0.0   5125.720031
# 506                         0.0                         0.0   5168.010506
# 507                         0.0                         0.0   5209.629553
# 508                         0.0                         0.0   5247.745395
# 509                         0.0                         0.0   5279.269307
#
# [510 rows x 16 columns]

# %%
figure = m.plot(forecast, xlabel='Date', ylabel='Crime Rate')

# %%
figure3 = m.plot_components(forecast)
